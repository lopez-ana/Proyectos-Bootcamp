# %%
import pandas as pd
import numpy as np

import sidetable as stb

import matplotlib.pyplot as plt
import seaborn as sns

from scipy.stats import skew
from scipy.stats import kurtosistest
from scipy import stats

plt.rcParams['figure.figsize'] = (10, 10)
pd.options.display.max_columns = None

from datetime import datetime

# %%
df = pd.read_pickle("../data/df_EDA.pkl")
df.head(2)
# Out:
#        fecha  estacion   año    mes festivo dia_sem laborable  \
# 0 2018-01-01  Invierno  2018  enero       0   lunes         0
# 1 2018-01-02  Invierno  2018  enero       0  martes         0
#
#   prevision_tiempo  sensacion_termica  humedad  velocidad_viento  \
# 0                2           18.18125  80.5833         10.749882
# 1                2           17.68695  69.6087         16.652113
#
#    alquiler_casual  alquiler_registrado  total_alquileres
# 0              331                  654               985
# 1              131                  670               801

# %%
#Hacemos dos listas con variables numéricas y variables categóricas

lista_num = ['sensacion_termica', 'humedad', 'velocidad_viento', 'alquiler_casual', 'alquiler_registrado', 'total_alquileres']
lista_cat = ['estacion', 'año', 'mes', 'festivo', 'dia_sem', 'laborable', 'prevision_tiempo']
lista_cat2 = ['año', 'mes', 'festivo', 'dia_sem', 'laborable', 'prevision_tiempo']

# %%
dict(enumerate(lista_num))
# Out:
# {0: 'sensacion_termica',
#  1: 'humedad',
#  2: 'velocidad_viento',
#  3: 'alquiler_casual',
#  4: 'alquiler_registrado',
#  5: 'total_alquileres'}

# %%
#Realizamos los boxplot de las variables numéricas

fig, axes = plt.subplots(3, 2, figsize=(15, 25))
axes = axes.flat

for indice, elemento in enumerate(lista_num):
    sns.boxplot(x = elemento, data = df, ax=axes[indice], color = "aquamarine")
    
    
plt.tight_layout()
plt.show();
# Out:
# C:\Users\anais\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\anais\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\anais\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\anais\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\anais\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\anais\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# CONCLUSIONES
#
# Estas son las columnas que presentan outliers:
#
#     -humedad: consideramos que humedad 0 es un error ya que es un valor que sólo se da en desiertos. Es sólo 1 registro así que lo gestionaremos.
#     -velocidad_viento: Entendemos que las medidas están en nudos. Entre 17 -22 nudos se considera fresco, entre 22 - 34 se considera fuerte y por encima de 34 nudos se considera temporal. Sólo tenemos un solo registro por encima de 34. Como nos parece un registro real, decidimos dejarlo como está.
#     -alquiler_casual: hay outliers, pero justo coinciden que en la "prevision_tiempo" era de 1, es decir, que era bueno. Por lo que el tiempo meteorológico afectó positivamente al alquiler de las bicis.
#     Finalmente, decidimos gestionar el dato 0 de "Humedad",transformando su valor a la mediana porque no queremos perder el registro entero para mantener todas las fechas de los dos años.

# %%
df[df['alquiler_casual'] > 3000]
# Out:
#          fecha   estacion   año         mes festivo    dia_sem laborable  \
# 184 2018-07-04     Verano  2018       julio       1  miercoles         0
# 440 2019-03-17   Invierno  2019       marzo       0    domingo         0
# 461 2019-04-07  Primavera  2019       abril       0    domingo         0
# 503 2019-05-19  Primavera  2019        mayo       0    domingo         0
# 511 2019-05-27  Primavera  2019        mayo       0      lunes         0
# 622 2019-09-15     Verano  2019  septiembre       0    domingo         0
# 643 2019-10-06      Otoño  2019     octubre       0    domingo         0
#
#     prevision_tiempo  sensacion_termica  humedad  velocidad_viento  \
# 184                2           33.27085  63.7917          5.459106
# 440                2           25.25230  75.5833          7.417168
# 461                1           21.30645  25.4167         18.416357
# 503                1           28.34540  45.6250          5.626325
# 511                1           32.07125  69.7083         14.416457
# 622                1           29.29335  50.1667         16.583907
# 643                1           26.92605  66.4167         17.957675
#
#      alquiler_casual  alquiler_registrado  total_alquileres
# 184             3065                 2978              6043
# 440             3155                 4681              7836
# 461             3252                 3605              6857
# 503             3410                 4884              8294
# 511             3283                 3308              6591
# 622             3160                 5554              8714
# 643             3031                 4934              7965

# %%
df[df['humedad'] == 0]
# Out:
#         fecha  estacion   año    mes festivo dia_sem laborable  \
# 68 2018-03-10  Invierno  2018  marzo       0  sabado         1
#
#    prevision_tiempo  sensacion_termica  humedad  velocidad_viento  \
# 68                3            19.2834      0.0         17.545759
#
#     alquiler_casual  alquiler_registrado  total_alquileres
# 68               46                  577               623

# %%
mediana = df["humedad"].median()

# %%
df.loc[68, ["humedad"]] = mediana

# %%
df.loc[68, ["humedad"]]
# Out:
# humedad    62.625
# Name: 68, dtype: object

# %%
df[df['velocidad_viento'] >= 34]
# Out:
#         fecha  estacion   año      mes festivo dia_sem laborable  \
# 49 2018-02-19  Invierno  2018  febrero       0   lunes         0
#
#    prevision_tiempo  sensacion_termica  humedad  velocidad_viento  \
# 49                1            19.5702  18.7917         34.000021
#
#     alquiler_casual  alquiler_registrado  total_alquileres
# 49              532                 1103              1635

# %%
#Realizamos los boxplot de las variables categoricas

fig, axes = plt.subplots(3, 2, figsize=(20, 30))
axes = axes.flat

for indice, elemento in enumerate(lista_cat2):
    sns.boxplot(y = "total_alquileres", x= elemento, data = df, ax=axes[indice], color = "teal")
    
    
plt.tight_layout()
plt.show()
# Out:
# C:\Users\anais\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\anais\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\anais\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\anais\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\anais\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\anais\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\anais\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\anais\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\anais\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\anais\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\anais\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\anais\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
df[df['total_alquileres'] <= 50]
# Out:
#          fecha estacion   año      mes festivo dia_sem laborable  \
# 666 2019-10-29    Otoño  2019  octubre       0  martes         1
#
#     prevision_tiempo  sensacion_termica  humedad  velocidad_viento  \
# 666                3              21.97     88.0           23.9994
#
#      alquiler_casual  alquiler_registrado  total_alquileres
# 666                2                   20                22

# %% [markdown]
# Como la "prevision_tiempo" tiene valor 3, es decir, había un poco de nieve, lluvia y truenos. Tiene sentido que solamente hubiera un alquiler de 22 en total y 2 de al quiler registrado. Por lo tanto, vamos a mantener este outlier.

# %%
df['festivo'].value_counts()
# Out:
# festivo
# 0    709
# 1     21
# Name: count, dtype: int64

# %% [markdown]
# CONCLUSION
#
# Hay outliers en la columna de festivos, ya que hay bastante más días que no son festivos (0) que días que son festivos (1)

# %%
df.to_pickle("../data/outliers_gestion.pkl")
df.to_csv("../data/df_tableau.csv")
